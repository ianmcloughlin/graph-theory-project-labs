# %% [markdown]
# # Factorial
#
# ***
#
# ![](https://metcentre.ie/wp-content/uploads/2022/04/ATU-Logo-Full-RGB-Green-big.jpg)

# %% [markdown]
# $$ y = x^3 $$

# %%
a = 1

# %%
a
# Out:
# 1

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.arange(30)

# %%
y = x**3

# %%
plt.plot(x, y)
